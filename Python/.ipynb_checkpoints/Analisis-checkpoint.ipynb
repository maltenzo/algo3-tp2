# %% [markdown]
# # Analisis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def correlacion_pearson(data_frame, columna1, columna2):
    return np.corrcoef(data_frame[columna1], data_frame[columna2])[0,1];

# %% [markdown]
# # Cargar el dataset con el resultado de los experimentos

# %%
df_resultados = pd.read_csv("resultados/resultado.csv");
display(df_resultados)
# Out:
#          dataset    n       m metodo  tiempo  costo
# 0   grafo-propio    3     3.0    ins  0.0181     76
# 1   grafo-propio    4     6.0    ins  0.0147    161
# 2   grafo-propio    5    10.0    ins  0.0148    206
# 3   grafo-propio    6    15.0    ins  0.0147     99
# 4   grafo-propio    7    21.0    ins  0.0163    112
# 5   grafo-propio    8    28.0    ins  0.0160    304
# 6   grafo-propio    9    36.0    ins  0.0176    299
# 7   grafo-propio   10    45.0    ins  0.0168    364
# 8   grafo-propio   11    55.0    ins  0.0177    610
# 9   grafo-propio   12    66.0    ins  0.0210    459
# 10  grafo-propio   13    78.0    ins  0.0222    595
# 11  grafo-propio   14    91.0    ins  0.0319    456
# 12  grafo-propio   15   105.0    ins  0.0234    438
# 13  grafo-propio   16   120.0    ins  0.0245    302
# 14  grafo-propio   17   136.0    ins  0.0474    670
# 15  grafo-propio   18   153.0    ins  0.0369    983
# 16  grafo-propio   19   171.0    ins  0.0260    629
# 17  grafo-propio   20   190.0    ins  0.0295    343
# 18  grafo-propio   21   210.0    ins  0.0323    772
# 19  grafo-propio   22   231.0    ins  0.0357    575
# 20  grafo-propio   23   253.0    ins  0.0506    943
# 21  grafo-propio   24   276.0    ins  0.0809   1336
# 22  grafo-propio   25   300.0    ins  0.0470   1399
# 23  grafo-propio   26   325.0    ins  0.0632    582
# 24  grafo-propio   27   351.0    ins  0.0634    770
# 25  grafo-propio   28   378.0    ins  0.0551    750
# 26  grafo-propio   29   406.0    ins  0.0575   1328
# 27  grafo-propio   30   435.0    ins  0.0801   1431
# 28  grafo-propio   31   465.0    ins  0.0643   1517
# 29  grafo-propio   32   496.0    ins  0.0676   1526
# ..           ...  ...     ...    ...     ...    ...
# 70  grafo-propio   73  2628.0    ins  0.5266   4196
# 71  grafo-propio   74  2701.0    ins  2.5910   2845
# 72  grafo-propio   75  2775.0    ins  0.4190   2978
# 73  grafo-propio   76  2850.0    ins  0.5331   3283
# 74  grafo-propio   77  2926.0    ins  0.5714   3513
# 75  grafo-propio   78  3003.0    ins  1.3000   3709
# 76  grafo-propio   79  3081.0    ins  0.5480   3454
# 77  grafo-propio   80  3160.0    ins  0.8964   3513
# 78  grafo-propio   81  3240.0    ins  0.5215   4106
# 79  grafo-propio   82  3321.0    ins  0.5673   2637
# 80  grafo-propio   83  3403.0    ins  0.6252   2724
# 81  grafo-propio   84  3486.0    ins  0.5701   3015
# 82  grafo-propio   85  3570.0    ins  0.6660   4616
# 83  grafo-propio   86  3655.0    ins  1.5587   3586
# 84  grafo-propio   87  3741.0    ins  1.9481   3255
# 85  grafo-propio   88  3828.0    ins  0.8520   4008
# 86  grafo-propio   89  3916.0    ins  1.9380   5250
# 87  grafo-propio   90  4005.0    ins  0.7540   4967
# 88  grafo-propio   91  4095.0    ins  0.7083   3130
# 89  grafo-propio   92  4186.0    ins  0.9016   4523
# 90  grafo-propio   93  4278.0    ins  1.1549   4223
# 91  grafo-propio   94  4371.0    ins  0.8699   4985
# 92  grafo-propio   95  4465.0    ins  0.7925   4370
# 93  grafo-propio   96  4560.0    ins  1.1624   4390
# 94  grafo-propio   97  4656.0    ins  1.3612   4356
# 95  grafo-propio   98  4753.0    ins  1.0803   4336
# 96  grafo-propio   99  4851.0    ins  1.0553   4575
# 97  grafo-propio  100  4950.0    ins  1.3865   3457
# 98  grafo-propio  101  5050.0    ins  3.4828   4875
# 99  grafo-propio  102  5151.0    ins  1.0108   4982
#
# [100 rows x 6 columns]

# %% [markdown]
# # Experimento grafos con pesos aleatorios
# ## Graficos para las heuristicas por:
# - Tiempo en relacion al tamanio
# - Costo en relacion al tamanio
# - Relacion entre costo y tiempo
#
# Estan en este orden los graficos

# %%
df_grafoPropio = df_resultados[df_resultados["dataset"]=="grafo-propio"].copy(); # lo usamos tambien abajo
fig = sns.scatterplot(data=df_grafoPropio, x='n', y='tiempo', hue='metodo');
fig.set(xlabel='n', ylabel='tiempo (ms)');

# Guardamos la figura
plt.savefig("graficos/tiempo-grafos-propios.svg");

# Graficamos segun heuristicas

# %%
fig = sns.scatterplot(data=df_grafoPropio, x='n', y='costo', hue='metodo');
fig.set(xlabel='n', ylabel='costos');

plt.savefig("graficos/costo-grafos-propios.svg");
## IGUAL AL DE ARRIBA PERO CON COSTOS

# %%
fig = sns.scatterplot(data=df_grafoPropio, x='tiempo', y='costo', hue='metodo');
fig.set(xlabel='tiempo (ms)', ylabel='calidad (costo)');


plt.savefig("graficos/costo-tiempo-grafos-propios.svg");

# %% [markdown]
# # Experimento 2
