# %% [markdown]
# # Analisis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def correlacion_pearson(data_frame, columna1, columna2):
    return np.corrcoef(data_frame[columna1], data_frame[columna2])[0,1];

# %%
df_resultados = pd.read_csv("resultados/resultado.csv");
display(df_resultados)
# Out:
#          dataset    n       m metodo  tiempo  costo
# 0   grafo-propio    3     3.0    ins  0.0181     76
# 1   grafo-propio    4     6.0    ins  0.0147    161
# 2   grafo-propio    5    10.0    ins  0.0148    206
# 3   grafo-propio    6    15.0    ins  0.0147     99
# 4   grafo-propio    7    21.0    ins  0.0163    112
# ..           ...  ...     ...    ...     ...    ...
# 95  grafo-propio   98  4753.0    ins  1.0803   4336
# 96  grafo-propio   99  4851.0    ins  1.0553   4575
# 97  grafo-propio  100  4950.0    ins  1.3865   3457
# 98  grafo-propio  101  5050.0    ins  3.4828   4875
# 99  grafo-propio  102  5151.0    ins  1.0108   4982
#
# [100 rows x 6 columns]

# %%
# Graficamos los tiempos de ejecucion en funcion de n
# respecto a la cantidad de vertices del grafo completo con pesos aleatorios

# %%
df_grafoPropio = df_resultados[df_resultados["dataset"]=="grafo-propio"].copy(); # lo usamos tambien abajo
fig = sns.scatterplot(data=df_grafoPropio, x='n', y='tiempo', hue='metodo');
# Graficamos segun heuristicas

# %%
# hue: agrupa los puntos segun esta lista, puede ser por string o numeros

# %%
df_grafoPropio = df_resultados[df_resultados["dataset"]=="grafo-propio"].copy(); # lo usamos tambien abajo
fig = sns.scatterplot(data=df_grafoPropio, x='n', y='costo', hue='metodo');
fig.set(xlabel='n', ylabel='costos');
plt.savefig("graficos/tiempo-grafos-propios.svg");
## IGUAL AL DE ARRIBA PERO CON COSTOS
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-1374dfd30c19> in <module>
#       2 fig = sns.scatterplot(data=df_grafoPropio, x='n', y='costo', hue='metodo');
#       3 fig.set(xlabel='n', ylabel='costos');
# ----> 4 plt.savefig("graficos/tiempo-grafos-propios.svg");
#       5 ## IGUAL AL DE ARRIBA PERO CON COSTOS
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/.local/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2096
#    2097             try:
# -> 2098                 result = print_method(
#    2099                     filename,
#    2100                     dpi=dpi,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1182
#    1183     def print_svg(self, filename, *args, **kwargs):
# -> 1184         with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1185
#    1186             filename = getattr(fh, 'name', '')
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'graficos/tiempo-grafos-propios.svg'

# %%
# Graficamos los costos en funcion de n
# respecto a la cantidad de vertices del grafo completo con pesos aleatorios

# %%
fig = sns.scatterplot(data=df_grafoPropio, x='n', y='costo', hue='metodo');
# Graficamos segun heuristicas

# %%
# hue: agrupa los puntos segun esta lista, puede ser por string o numeros

# %%
fig.set(xlabel='n', ylabel='calidad (costo)');
plt.savefig("graficos/costo-grafos-propios.svg");
# Graficamos los tiempos de ejecucion en funcion de n
# respecto a la cantidad de vertices del grafo completo con pesos aleatorios
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-536046cf7f87> in <module>
#       1 fig.set(xlabel='n', ylabel='calidad (costo)');
# ----> 2 plt.savefig("graficos/costo-grafos-propios.svg");
#       3 # Graficamos los tiempos de ejecucion en funcion de n
#       4 # respecto a la cantidad de vertices del grafo completo con pesos aleatorios
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/.local/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2096
#    2097             try:
# -> 2098                 result = print_method(
#    2099                     filename,
#    2100                     dpi=dpi,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1182
#    1183     def print_svg(self, filename, *args, **kwargs):
# -> 1184         with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1185
#    1186             filename = getattr(fh, 'name', '')
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'graficos/costo-grafos-propios.svg'

# %%
fig = sns.scatterplot(data=df_grafoPropio, x='tiempo', y='costo', hue='metodo');
# Graficamos segun heuristicas

# %%
# hue: agrupa los puntos segun esta lista, puede ser por string o numeros

# %%
fig.set(xlabel='tiempo (ms)', ylabel='calidad (costo)');
plt.savefig("graficos/tiempo-costo-grafos-propios.svg");
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-ef96e26bf6da> in <module>
#       1 fig.set(xlabel='tiempo (ms)', ylabel='calidad (costo)');
# ----> 2 plt.savefig("graficos/tiempo-costo-grafos-propios.svg");
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~/.local/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2096
#    2097             try:
# -> 2098                 result = print_method(
#    2099                     filename,
#    2100                     dpi=dpi,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1182
#    1183     def print_svg(self, filename, *args, **kwargs):
# -> 1184         with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1185
#    1186             filename = getattr(fh, 'name', '')
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'graficos/tiempo-costo-grafos-propios.svg'
